# %%
from VehicleTracker import VehicleTracker
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
test_img = mpimg.imread('../test_images/test6.jpg')
plt.imshow(test_img)
plt.show()

# %% [markdown]
# ### Train that Classifier

# %%
tracker = VehicleTracker(test_img.shape, heatmap_threshold=20)
# Out:
# Retraining Car Classifier
# Length of Vehicle Dataset: 8792
# Length of Non-Vehicle Dataset: 8968
# 8.2 Seconds to train SVC...
# Test Accuracy of SVC =  0.987894144144
# Saving Classifier and Feature Scaler.

# %%
init_img, box_list, heatmap, final_img = tracker.pipeline(test_img, threshold=0.75)
plt.imshow(init_img)
plt.show()
plt.imsave('../output_images/single_image_detection.jpg', init_img)

# %%
plt.imshow(heatmap)
plt.show()
plt.imsave('../output_images/heatmap_image_detection.jpg', heatmap)

# %%
plt.imshow(final_img)
plt.show()
plt.imsave('../output_images/final_image_detection.jpg', final_img)

# %%
clip = VideoFileClip('../project_video.mp4')
out_clip = clip.fl_image(tracker.video_pipeline)
out_clip.write_videofile('project_video_output2.mp4',audio=False)
# Out:
# [MoviePy] >>>> Building video project_video_output2.mp4
# [MoviePy] Writing video project_video_output2.mp4
# 100%|█████████▉| 1260/1261 [16:44<00:00,  1.28it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: project_video_output2.mp4
